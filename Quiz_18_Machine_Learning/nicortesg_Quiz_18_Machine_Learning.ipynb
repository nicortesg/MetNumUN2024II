# %% [markdown]
# La primera modificacion realizada fue cambiar el modelo lineal y usé Random Forest Regressor ya que es ideal para datos no lineales y complejos. También usa múltiples árboles de decisión para mejorar la precisión y reducir el riesgo de sobreajuste.<br><br>
#
# Se usó stocks.load_spx_data en lugar de stocks.load_ndx_data como se indicó. Esto para usar el mercado que nos indico el profe S&P 500.<br><br>
#
# Se eligieron 20 acciones:
# "NYS:ABBV", "NYS:ABT", "NYS:ACN", "NYS:ADM", "NYS:AFL", "NYS:AIG", "NYS:ALL", "NYS:AMT", "NYS:APD", "NYS:APH", "NYS:ARE", "NYS:AVB", "NYS:AXP", "NYS:BA", "NYS:BAC", "NYS:BDX", "NYS:BLK", "NYS:CCI", "NYS:CL", "NYS:CVX".<br><br>
#
# Ya que Muchas de estas empresas son líderes en sus respectivos sectores, proporcionando una base sólida para los inversores.<br><br>
#
# Se aplicó el campo is_liquid para manejar únicamente los activos líquidos y luego se ajustaron los pesos usando esa informacion.<br><br>
#
# Se modificaron los Targets indicados:<br>
# class_positive = 1 # prices goes up<br>
# class_negative = 0 # price goes down<br>
# for<br>
# class_positive = 1 # prices goes up more than 0.1%<br>
# class_neutral = 0 # prices goes up or don las that 0.1%<br>
# class_negative = -1 # price goes down more than 0.1%<br><br>
#
# Se Añadio el filtro para manejar únicamente los activos liquidos.<br><br>
# ![image.png](data:image/png;base64,...)
# <br><br>
# Además se añadio el indicador Trix debido a que es útil en los algoritmos de negociación porque ayuda a suavizar los movimientos de los precios, reduciendo el ruido del mercado y destacando la tendencia subyacente. Es un oscilador de impulso que muestra la tasa porcentual de cambio de una media móvil triple suavizada exponencialmente. Esto hace que el TRIX sea eficaz para identificar condiciones de sobrecompra o sobreventa y posibles cambios de tendencia, lo que permite a los operadores tomar decisiones más informadas. Además, su capacidad para filtrar las fluctuaciones a corto plazo lo hace valioso para desarrollar algoritmos centrados en estrategias de seguimiento de tendencias a más largo plazo.<br><br>

# %% [markdown]
# **3 Pruebas:**

# %% [markdown]
# Only Longs: Target para operar solo longs (>0.5%)<br><br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Only short: Target para operar solo Shorts (<0.5%): <br><br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For both (goes up or down):<br><br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Plots and Test:<br><br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)
